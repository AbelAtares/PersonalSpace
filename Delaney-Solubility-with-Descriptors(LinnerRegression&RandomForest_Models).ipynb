# %% [markdown]
# <a href="https://colab.research.google.com/github/AbelAtares/PersonalSpace/blob/main/Delaney-Solubility-with-Descriptors(LinnerRegression%26RandomForest_Models).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Linear Regression Model**

# %% [markdown]
# Delaney-Solubility-with-Descriptors
# Welcome to the "Delaney Solubility with Descriptors" project! This repository features a machine learning model designed to predict the solubility of compounds using various molecular descriptors. 📊🔬

# %% [markdown]
# ## **Loading and preparing data**

# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dataprofessor/data/refs/heads/master/delaney_solubility_with_descriptors.csv')
df
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion   logS
# 0     2.59540  167.850                0.0            0.000000 -2.180
# 1     2.37650  133.405                0.0            0.000000 -2.000
# 2     2.59380  167.850                1.0            0.000000 -1.740
# 3     2.02890  133.405                1.0            0.000000 -1.480
# 4     2.91890  187.375                1.0            0.000000 -3.040
# ...       ...      ...                ...                 ...    ...
# 1139  1.98820  287.343                8.0            0.000000  1.144
# 1140  3.42130  286.114                2.0            0.333333 -4.925
# 1141  3.60960  308.333                4.0            0.695652 -3.893
# 1142  2.56214  354.815                3.0            0.521739 -3.790
# 1143  2.02164  179.219                1.0            0.461538 -2.581
#
# [1144 rows x 5 columns]

# %%
X=df.drop('logS',axis=1)
X
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 0     2.59540  167.850                0.0            0.000000
# 1     2.37650  133.405                0.0            0.000000
# 2     2.59380  167.850                1.0            0.000000
# 3     2.02890  133.405                1.0            0.000000
# 4     2.91890  187.375                1.0            0.000000
# ...       ...      ...                ...                 ...
# 1139  1.98820  287.343                8.0            0.000000
# 1140  3.42130  286.114                2.0            0.333333
# 1141  3.60960  308.333                4.0            0.695652
# 1142  2.56214  354.815                3.0            0.521739
# 1143  2.02164  179.219                1.0            0.461538
#
# [1144 rows x 4 columns]

# %%
Y=df['logS']
Y
# Out:
# 0      -2.180
# 1      -2.000
# 2      -1.740
# 3      -1.480
# 4      -3.040
#         ...
# 1139    1.144
# 1140   -4.925
# 1141   -3.893
# 1142   -3.790
# 1143   -2.581
# Name: logS, Length: 1144, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=11)

# %%
X_train, X_test
# Out:
# (      MolLogP    MolWt  NumRotatableBonds  AromaticProportion
#  1021 -7.57140  504.438                8.0            0.000000
#  123   7.92740  395.327                1.0            0.631579
#  961   1.35060  151.165                1.0            0.545455
#  26    1.05940  118.176                5.0            0.000000
#  1107  2.83260  112.216                0.0            0.000000
#  ...       ...      ...                ...                 ...
#  850   2.43350  198.653                1.0            0.461538
#  583   4.60460  266.340                3.0            0.600000
#  332   5.76304  256.348                0.0            0.900000
#  1115  0.83340  253.269                1.0            0.842105
#  1104  2.82402  150.221                1.0            0.545455
#
#  [915 rows x 4 columns],
#        MolLogP    MolWt  NumRotatableBonds  AromaticProportion
#  60     3.3517  179.101                5.0            0.000000
#  326    1.1051  224.260                3.0            0.000000
#  671    6.3720  376.496                9.0            0.642857
#  584    7.7256  474.640                1.0            0.000000
#  651    0.5694   88.106                1.0            0.000000
#  ...       ...      ...                ...                 ...
#  277    2.0026  324.336                4.0            0.500000
#  1124   5.3915  333.604                5.0            0.352941
#  346    4.7284  243.309                0.0            0.947368
#  665    2.2490  106.168                1.0            0.750000
#  437    0.8549  150.181                2.0            0.545455
#
#  [229 rows x 4 columns])

# %%
Y_train
# Out:
# 1021   -0.410
# 123    -8.940
# 961    -1.030
# 26     -0.770
# 1107   -4.470
#         ...
# 850    -2.890
# 583    -4.950
# 332    -7.010
# 1115   -2.404
# 1104   -2.220
# Name: logS, Length: 915, dtype: float64

# %%
Y_test
# Out:
# 60     -4.430
# 326    -2.253
# 671    -8.600
# 584    -7.278
# 651    -0.040
#         ...
# 277    -4.470
# 1124   -5.752
# 346    -6.200
# 665    -2.770
# 437    -0.950
# Name: logS, Length: 229, dtype: float64

# %% [markdown]
# ## **Model**

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train,Y_train)
# Out:
# 0.7767801152371718

# %%
Y_pred=lr.predict(X_test)
Y_pred
# Out:
# array([-3.33263647, -2.00635893, -7.10969195, -8.64778076, -0.70883742,
#        -1.12344413,  0.74115997, -2.81288566, -2.58623682,  0.86896718,
#        -3.13730931, -1.73407391, -4.70185331, -1.86457861, -0.25727039,
#        -4.01723516, -4.26004375, -3.89931203, -1.18559267, -3.59637834,
#        -0.14478055, -1.27781376, -3.07148169, -1.85030284, -4.28692025,
#        -4.1608926 , -4.30065851, -1.95862477, -2.11660729, -1.60941565,
#        -4.97107491, -7.22713935, -5.76306848, -3.60602879, -0.43011283,
#        -0.47937367, -2.88135755,  0.05129009, -0.75739924, -3.14219638,
#        -3.65117946, -2.20257941, -1.98162838, -2.68272356, -3.58947917,
#        -2.23130837, -4.56907178, -2.69957414, -1.58980358, -3.99253023,
#        -2.21301788, -1.4793025 , -3.87412985, -1.98082363, -2.96245728,
#        -2.2867618 , -1.81560537, -2.06824566, -4.14061071, -2.84685403,
#        -0.49769374, -6.61087968, -4.18542535, -3.91119581, -0.98937955,
#        -1.80118052, -1.24046524, -3.50610734, -4.98919689, -4.04045017,
#        -4.7153058 , -2.97499892, -1.94236518, -2.71540469, -3.23720039,
#        -4.95227092, -5.24722668, -2.2490396 , -2.48231007, -2.34620377,
#        -0.78468875, -1.52207209, -3.4951245 , -1.98162838, -0.92530856,
#        -1.70589223, -4.99405615, -1.15851337, -1.83175382, -1.42756185,
#        -6.09537521, -2.62416187, -2.65808184, -3.11553692, -1.79743228,
#        -5.42388451, -2.59791005, -1.63350557, -3.31544917, -0.69316521,
#        -3.35848067, -1.43468474, -2.53064594, -4.21469557, -1.69806646,
#         1.78343061, -1.10810407, -0.57775612, -3.20991389, -6.39048233,
#        -2.00069699, -2.24794309, -6.06108085, -3.01777502, -1.40206106,
#        -4.24406747, -3.4899464 , -4.6549099 , -0.56280673, -1.89186293,
#        -1.89225128, -3.39895662, -3.65109616, -2.28885364, -2.57785354,
#        -1.69462699, -3.4899464 , -3.75143052, -1.36187671,  1.78343061,
#        -4.99405615, -2.16468569, -1.39568551, -4.26284243, -0.33865823,
#        -2.98225819, -2.43029913, -1.55973688, -2.61812229, -4.24911122,
#        -1.42010836, -4.17024965, -1.35511238, -4.22071879, -4.99405615,
#         0.27310593, -0.75392376, -0.71809304, -0.40770953, -2.675885  ,
#        -2.3777188 , -0.48561947, -2.31018855, -1.79507773, -7.01156196,
#        -2.42289394, -1.64870819, -3.71535731, -0.65559762, -2.06824566,
#        -2.34620377, -2.40534735, -9.20837503, -2.62710293,  1.21802492,
#        -2.26510492, -6.66277353, -0.66170267, -4.34967223, -1.41536362,
#        -2.41949631, -1.40206106, -1.8283513 , -3.07148169, -6.4518869 ,
#        -3.06008861, -2.99539625, -1.26624963, -1.09707392, -3.93591952,
#        -4.56177575, -6.39048233, -4.45026366, -0.93711348, -1.44202158,
#        -2.81480077, -0.03753034, -2.39266099, -1.81624902, -2.06480618,
#        -3.51720885, -4.50561407, -2.11660729, -4.21065967, -5.93643247,
#        -2.12679171, -4.67719255, -2.22625233, -3.24422735, -2.28595252,
#        -1.21940634, -2.66000379, -3.22881995, -2.35100283, -4.12684438,
#        -4.5423152 , -1.55577187, -2.03559731, -3.76459398, -4.27680988,
#        -3.40982484, -2.80860405, -1.23702577, -2.92991259, -3.35650711,
#        -2.55973339, -4.2679577 , -1.67126881, -3.59637834, -3.0147637 ,
#        -1.26419655, -1.72715392, -5.48257743, -1.83217346, -3.53466675,
#        -6.0357265 , -5.23203746, -2.36809282, -1.54214382])

# %%
Y_test
# Out:
# 60     -4.430
# 326    -2.253
# 671    -8.600
# 584    -7.278
# 651    -0.040
#         ...
# 277    -4.470
# 1124   -5.752
# 346    -6.200
# 665    -2.770
# 437    -0.950
# Name: logS, Length: 229, dtype: float64

# %% [markdown]
# ## **Model evaluation**

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
lr_mse_train=mean_squared_error(Y_test,Y_pred)
lr_r2_score_train=r2_score(Y_test,Y_pred)
print(lr_mse_train)
print(lr_r2_score_train)
# Out:
# 1.0777462873363313
# 0.7377238790185194

# %% [markdown]
# ## **Data visualization**

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(Y_test,Y_pred,alpha=0.3)
plt.xlabel('Experimental logS')
plt.ylabel('Predicted logS')
# Out:
# Text(0, 0.5, 'Predicted logS')

# %%
plt.scatter(Y_train,lr.predict(X_train),alpha=0.3)

# %% [markdown]
# ## **Apenddix: Random Forest**

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor(max_depth=2,random_state=11)
rf.fit(X_train,Y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=11)

# %%
Y_rf_pred=rf.predict(X_test)
Y_rf_pred
# Out:
# array([-4.30061934, -1.43556358, -7.0225288 , -7.0225288 , -1.17107369,
#        -1.4188296 , -1.17107369, -3.94999594, -2.26718118, -1.32895675,
#        -4.33559087, -1.39171659, -4.40471016, -1.54311615, -1.32895675,
#        -4.30061934, -2.94346132, -4.40471016, -1.25114177, -4.3679013 ,
#        -1.17107369, -1.32671212, -2.56741463, -1.3852331 , -4.40471016,
#        -2.65728748, -4.40471016, -1.67380789, -1.54311615, -1.27998904,
#        -4.40471016, -4.30061934, -7.0225288 , -2.35705404, -1.32895675,
#        -1.32895675, -1.4188296 , -1.4188296 , -1.17107369, -2.58213397,
#        -4.40471016, -2.26718118, -1.3852331 , -4.05919424, -4.05919424,
